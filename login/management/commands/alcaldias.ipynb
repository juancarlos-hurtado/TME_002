# %%
import pandas as pd

# %%
alcaldias_df = pd.read_csv('alcaldias.csv')

# %%
alcaldias_df
# Out:
#                   alcaldia  cve_alcaldia           entidad  cve_ent  cvegeo  \
# 0               Milpa Alta             9  Ciudad de México        9    9009
# 1            Benito Juárez            14  Ciudad de México        9    9014
# 2        Gustavo A. Madero             5  Ciudad de México        9    9005
# 3                 Coyoacán             3  Ciudad de México        9    9003
# 4           Miguel Hidalgo            16  Ciudad de México        9    9016
# 5   La Magdalena Contreras             8  Ciudad de México        9    9008
# 6                  Tláhuac            11  Ciudad de México        9    9011
# 7             Azcapotzalco             2  Ciudad de México        9    9002
# 8                Iztacalco             6  Ciudad de México        9    9006
# 9           Álvaro Obregón            10  Ciudad de México        9    9010
# 10              Xochimilco            13  Ciudad de México        9    9013
# 11     Venustiano Carranza            17  Ciudad de México        9    9017
# 12                 Tlalpan            12  Ciudad de México        9    9012
# 13   Cuajimalpa de Morelos             4  Ciudad de México        9    9004
# 14              Cuauhtémoc            15  Ciudad de México        9    9015
# 15              Iztapalapa             7  Ciudad de México        9    9007
#
#                                             geo_shape    latitud   longitud
# 0   {"type": "Polygon", "coordinates": [[[-98.9972...  19.139457 -99.051095
# 1   {"type": "Polygon", "coordinates": [[[-99.1367...  19.380642 -99.161135
# 2   {"type": "Polygon", "coordinates": [[[-99.1185...  19.504065 -99.115864
# 3   {"type": "Polygon", "coordinates": [[[-99.1392...  19.326667 -99.150376
# 4   {"type": "Polygon", "coordinates": [[[-99.1905...  19.428062 -99.204567
# 5   {"type": "Polygon", "coordinates": [[[-99.2085...  19.268977 -99.268413
# 6   {"type": "Polygon", "coordinates": [[[-98.9789...  19.276998 -99.002822
# 7   {"type": "Polygon", "coordinates": [[[-99.1823...  19.485329 -99.182107
# 8   {"type": "Polygon", "coordinates": [[[-99.0558...  19.396912 -99.094330
# 9   {"type": "Polygon", "coordinates": [[[-99.1887...  19.336176 -99.246820
# 10  {"type": "Polygon", "coordinates": [[[-99.0986...  19.245145 -99.090364
# 11  {"type": "Polygon", "coordinates": [[[-99.1089...  19.430495 -99.093106
# 12  {"type": "Polygon", "coordinates": [[[-99.1962...  19.198340 -99.206221
# 13  {"type": "Polygon", "coordinates": [[[-99.2569...  19.324634 -99.310729
# 14  {"type": "Polygon", "coordinates": [[[-99.1291...  19.431373 -99.149056
# 15  {"type": "Polygon", "coordinates": [[[-99.0581...  19.349166 -99.056799

# %%
alcaldias_df = alcaldias_df.drop(columns = ['cve_alcaldia', 'entidad', 'cve_ent', 'cvegeo', 'geo_shape'])
alcaldias_df
# Out:
#                   alcaldia    latitud   longitud
# 0               Milpa Alta  19.139457 -99.051095
# 1            Benito Juárez  19.380642 -99.161135
# 2        Gustavo A. Madero  19.504065 -99.115864
# 3                 Coyoacán  19.326667 -99.150376
# 4           Miguel Hidalgo  19.428062 -99.204567
# 5   La Magdalena Contreras  19.268977 -99.268413
# 6                  Tláhuac  19.276998 -99.002822
# 7             Azcapotzalco  19.485329 -99.182107
# 8                Iztacalco  19.396912 -99.094330
# 9           Álvaro Obregón  19.336176 -99.246820
# 10              Xochimilco  19.245145 -99.090364
# 11     Venustiano Carranza  19.430495 -99.093106
# 12                 Tlalpan  19.198340 -99.206221
# 13   Cuajimalpa de Morelos  19.324634 -99.310729
# 14              Cuauhtémoc  19.431373 -99.149056
# 15              Iztapalapa  19.349166 -99.056799

# %%
alcaldias_df.columns = ['nombre', 'latitud', 'longitud']

# %%
alcaldias_df.dtypes
# Out:
# nombre       object
# latitud     float64
# longitud    float64
# dtype: object
