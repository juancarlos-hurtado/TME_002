# %%
import pandas as pd

# %%
estados_df = pd.read_json('estados_mx.json')

# %%
estados_df = estados_df[['nombre', 'clave']]
estados_df
# Out:
#                  nombre clave
# 0        AGUASCALIENTES   AGS
# 1       BAJA CALIFORNIA    BC
# 2   BAJA CALIFORNIA SUR   BCS
# 3             CHIHUAHUA   CHI
# 4               CHIAPAS   CHS
# 5              CAMPECHE   CMP
# 6      CIUDAD DE MEXICO   CMX
# 7              COAHUILA   COA
# 8                COLIMA   COL
# 9               DURANGO   DGO
# 10             GUERRERO   GRO
# 11           GUANAJUATO   GTO
# 12              HIDALGO   HGO
# 13              JALISCO   JAL
# 14            MICHOACAN   MCH
# 15     ESTADO DE MEXICO   MEX
# 16              MORELOS   MOR
# 17              NAYARIT   NAY
# 18           NUEVO LEON    NL
# 19               OAXACA   OAX
# 20               PUEBLA   PUE
# 21         QUINTANA ROO    QR
# 22            QUERETARO   QRO
# 23              SINALOA   SIN
# 24      SAN LUIS POTOSI   SLP
# 25               SONORA   SON
# 26              TABASCO   TAB
# 27             TLAXCALA   TLX
# 28           TAMAULIPAS   TMS
# 29             VERACRUZ   VER
# ...
